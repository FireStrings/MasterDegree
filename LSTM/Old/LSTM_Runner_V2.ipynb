# %% [markdown]
# <a href="https://colab.research.google.com/github/FireStrings/MasterDegree/blob/main/LSTM/Old/LSTM_Runner_V2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)

import os
os.chdir("/content/drive/My Drive/UFSCAR/Notebooks/LSTM")
# Out:
# Mounted at /content/drive/

# %% [markdown]
# ### Imports

# %%
# %run LSTMV2.ipynb
# Out:
# Mounted at /content/drive/

# %%
# lista_estacoes = ["campo_grande", "curitiba", "manaus", "minas_gerais_gv", "belem", "pelotas", "brasilia", "minas_gerais_bh"]
lista_estacoes = ["brasilia"]
janela_tempo = 11
results_lstm = {}
results_bilstm = {}

# %%
for estacao in lista_estacoes:
    anual_df = load_and_filter(estacao, 7, 18).set_index("data_hora")

    train_size = int(0.7 * (round(len(anual_df)/10)*10))

    train_df = anual_df.iloc[0:train_size]
    test_df = anual_df.iloc[train_size:]

    results_lstm[estacao] = {}
    results_bilstm[estacao] = {}

    # LSTM
    process_lstm(5, estacao, train_df, test_df, results_lstm, True, False, False)

    # BiLSTM
    # process_lstm(5, estacao, train_df, test_df, results_bilstm, True, True, False)
# Out:
# Starting process 0 for station brasilia with LSTM type
# Starting process 1 for station brasilia with LSTM type
# Starting process 2 for station brasilia with LSTM type
# Starting process 3 for station brasilia with LSTM type
# Starting process 4 for station brasilia with LSTM type

# %%
list_df_results = []
for estacao in lista_estacoes:
    list_df_results.append(create_table_results(estacao, "lstm", results_lstm[estacao]))
    # list_df_results.append(create_table_results(estacao, "bilstm", results_bilstm[estacao]))

# %%
df_final = pd.concat(list_df_results, axis=0)

# %%
# df_final.groupby(level=[0, 1]).mean().reset_index()
df_final
# Out:
#                                   mse      rmse       mae        r2
# estacao  tipo_rede execucao
# brasilia lstm      1         0.539781  0.734698  0.654796  0.443045
#                    2         0.336820  0.580362  0.490834  0.600934
#                    3         0.149545  0.386710  0.241070  0.842448
#                    4         0.182536  0.427243  0.301594  0.791886
#                    5         0.164280  0.405315  0.271935  0.802402

# %%
pd.set_option('display.max_rows', 100)

# %%
df_final
# Out:
#                                   mse      rmse       mae        r2
# estacao  tipo_rede execucao
# brasilia lstm      1         0.185890  0.431149  0.325926  0.809765
#                    2         0.194427  0.440938  0.318781  0.792522
#                    3         0.190652  0.436637  0.314042  0.751580
#                    4         0.145716  0.381728  0.227699  0.848361
#                    5         0.268895  0.518551  0.413504  0.665965
